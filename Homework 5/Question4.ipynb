# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
iterations = 500

mu = 0
alpha = 0.75
sigma2 = 1
y = np.zeros((iterations))
for i in range(1,iterations):
  e = np.random.normal(0,sigma2)
  y[i] =  mu + alpha*(y[i-1] - mu) + e

# %%
plt.plot(y)
